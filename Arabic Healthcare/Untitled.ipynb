# %%
import pandas as pd

# %%
pd.read_csv("AHQAD.csv", encoding="utf-8")
# Out:
#         Unnamed: 0                                           Question  \
# 0                0  اجريت صورة رنين مغناطيسي للثدي ظهر منطقة تعزيز...
# 1                1  انا اعاني من اشياء تجبرني على فعل امور لا اريد...
# 2                2  أريد الاستفسار عن مضاعفات عملية استئصال ورم ال...
# 3                3  اليوم حاسس ان عندى حاجه فى الدبر من جوا مش عاي...
# 4                4  ليه فجأة بحس انى مش عارفة اتنفس وجسمى بينمل وي...
# ...            ...                                                ...
# 808467      808467  المشكل عندي هو بروز قطرات بعد الانتهاء من التب...
# 808468      808468  سؤال اشكي من الالم في الضهر منذو اشهر عندما اك...
# 808469      808469  لدي حبيبات صغيرة على حافة الذكرأي محيطة عليه و...
# 808470      808470  سماع وش وصفافيرباصوات مختلفة بالاذنين متواصل د...
# 808471      808471  شخص مريض بداء التاهب الكبد الفيروسي نوع سي و ه...
#
#                                                    Answer  \
# 0       المهم بالموضوع ما هي درجة ال BIRADS الموصوفة ل...
# ...
